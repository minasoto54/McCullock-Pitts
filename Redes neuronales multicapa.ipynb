# %% [markdown]
# <a href="https://colab.research.google.com/github/minasoto54/McCullock-Pitts/blob/main/Redes%20neuronales%20multicapa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Generar dataset sintético con diferentes rangos por habilidad
n_muestras = 5000
# Habilidades técnicas: 70-100
tec = np.random.randint(70, 101, (n_muestras, 6))
# Habilidades matemáticas: 60-90
mat = np.random.randint(60, 91, (n_muestras, 6))
# Habilidades psicológicas: 50-85
psi = np.random.randint(50, 86, (n_muestras, 6))
# Nombres de columnas
columnas = [
    'python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube',
        'estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado',
            'trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas'
]
# Crear DataFrame
df = pd.DataFrame(np.concatenate([tec, mat, psi], axis=1), columns=columnas)

# %%
df
# Out:
#       python  sql  visualizacion_datos  excel  manejo_apis  nube  estadistica  \
# 0         89   89                   98     79           96    83           63
# 1         92   87                   86     83           94    73           77
# 2         88   86                   84     92           99    93           65
# 3         90   86                   80     79          100    95           84
# 4         78   87                   79     72           77    72           65
# ...      ...  ...                  ...    ...          ...   ...          ...
# 4995      99   97                   79     72           71    88           83
# 4996      70   83                   79     88           72    74           62
# 4997      91   70                   72     98           89    93           90
# 4998      86   82                   87     71           99    94           73
# 4999      97   78                   75     89           81    82           86
#
#       probabilidad  algebra_lineal  calculo  optimizacion  modelado  \
# 0               86              88       63            84        72
# 1               70              81       63            74        61
# 2               78              79       67            63        63
# 3               88              62       86            84        61
# 4               82              77       89            81        69
# ...            ...             ...      ...           ...       ...
# 4995            86              75       75            79        63
# 4996            83              66       77            67        85
# 4997            73              80       73            61        88
# 4998            75              68       74            63        65
# 4999            75              70       60            86        90
#
#       trabajo_equipo  comunicacion  creatividad  adaptabilidad  liderazgo  \
# 0                 69            73           84             85         82
# 1                 57            53           69             61         62
# 2                 84            85           66             52         78
# 3                 68            55           78             80         61
# 4                 82            68           65             82         59
# ...              ...           ...          ...            ...        ...
# 4995              53            51           77             71         56
# 4996              80            55           65             66         57
# 4997              59            79           59             62         68
# 4998              59            83           58             64         69
# 4999              76            82           71             74         62
#
#       resolucion_problemas
# 0                       53
# 1                       70
# 2                       76
# 3                       61
# 4                       66
# ...                    ...
# 4995                    68
# 4996                    51
# 4997                    59
# 4998                    67
# 4999                    64
#
# [5000 rows x 18 columns]

# %%
# Calcular promedio por grupo y promedio total
prom_tecnologicas = df[['python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube']].mean(axis=1)
prom_matematicas  = df[['estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado']].mean(axis=1)
prom_psicologicas = df[['trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas']].mean(axis=1)
# Promedio total = promedio de los 3 promedios
prom_total = (prom_tecnologicas + prom_matematicas + prom_psicologicas) / 3
# Etiqueta: 1 = apto si promedio total > 80
y = (prom_total > 75).astype(int)
# one-hot encoding
y = pd.get_dummies(y).values

# %%
y
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [False,  True],
#        [ True, False],
#        [False,  True]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42
    )

    # Escalamiento
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
modelo = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')
])

adam = Adam(learning_rate=0.001)
modelo.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = modelo.fit(
  X_train, y_train,
  epochs=50,
  batch_size=8,
  validation_data=(X_test, y_test),
  verbose=1
)
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8161 - loss: 0.3753 - val_accuracy: 0.9550 - val_loss: 0.1103
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9639 - loss: 0.0854 - val_accuracy: 0.9660 - val_loss: 0.0731
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0502 - val_accuracy: 0.9740 - val_loss: 0.0586
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9865 - loss: 0.0367 - val_accuracy: 0.9700 - val_loss: 0.0628
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9873 - loss: 0.0324 - val_accuracy: 0.9660 - val_loss: 0.0859
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9913 - loss: 0.0239 - val_accuracy: 0.9740 - val_loss: 0.0662
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0209 - val_accuracy: 0.9790 - val_loss: 0.0640
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9925 - loss: 0.0189 - val_accuracy: 0.9690 - val_loss: 0.0893
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9939 - loss: 0.0150 - val_accuracy: 0.9720 - val_loss: 0.0685
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9977 - loss: 0.0095 - val_accuracy: 0.9760 - val_loss: 0.0584
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9954 - loss: 0.0100 - val_accuracy: 0.9740 - val_loss: 0.0762
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - loss: 0.0139 - val_accuracy: 0.9680 - val_loss: 0.1159
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0216 - val_accuracy: 0.9640 - val_loss: 0.1365
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9945 - loss: 0.0184 - val_accuracy: 0.9740 - val_loss: 0.0718
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 0.9740 - val_loss: 0.0870
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.6113e-04 - val_accuracy: 0.9810 - val_loss: 0.0614
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 5.2225e-04 - val_accuracy: 0.9820 - val_loss: 0.0654
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.8171e-04 - val_accuracy: 0.9790 - val_loss: 0.0631
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.0928e-04 - val_accuracy: 0.9800 - val_loss: 0.0685
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6003e-04 - val_accuracy: 0.9810 - val_loss: 0.0680
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0597e-04 - val_accuracy: 0.9800 - val_loss: 0.0705
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 7.3354e-05 - val_accuracy: 0.9810 - val_loss: 0.0723
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.9392e-05 - val_accuracy: 0.9820 - val_loss: 0.0764
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.9013e-05 - val_accuracy: 0.9810 - val_loss: 0.0784
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.8090e-05 - val_accuracy: 0.9820 - val_loss: 0.0821
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.8326e-05 - val_accuracy: 0.9810 - val_loss: 0.0843
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.7624e-05 - val_accuracy: 0.9790 - val_loss: 0.0835
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6661e-05 - val_accuracy: 0.9810 - val_loss: 0.0841
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.7245e-06 - val_accuracy: 0.9810 - val_loss: 0.0885
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.9140e-06 - val_accuracy: 0.9810 - val_loss: 0.0870
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 6.6802e-06 - val_accuracy: 0.9800 - val_loss: 0.0901
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 5.0743e-06 - val_accuracy: 0.9810 - val_loss: 0.0933
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.0200e-06 - val_accuracy: 0.9800 - val_loss: 0.0969
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.9328e-06 - val_accuracy: 0.9800 - val_loss: 0.1002
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.8401e-06 - val_accuracy: 0.9810 - val_loss: 0.1055
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3051e-06 - val_accuracy: 0.9810 - val_loss: 0.1038
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0800e-06 - val_accuracy: 0.9790 - val_loss: 0.1067
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 7.2373e-07 - val_accuracy: 0.9800 - val_loss: 0.1094
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 5.0261e-07 - val_accuracy: 0.9780 - val_loss: 0.1125
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.6472e-07 - val_accuracy: 0.9770 - val_loss: 0.1122
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.1619e-07 - val_accuracy: 0.9760 - val_loss: 0.1105
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.0946e-07 - val_accuracy: 0.9780 - val_loss: 0.1146
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.9101e-07 - val_accuracy: 0.9790 - val_loss: 0.1174
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.2581e-07 - val_accuracy: 0.9800 - val_loss: 0.1152
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.5271e-08 - val_accuracy: 0.9760 - val_loss: 0.1246
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.8620e-08 - val_accuracy: 0.9770 - val_loss: 0.1260
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.4774e-08 - val_accuracy: 0.9770 - val_loss: 0.1230
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.1348e-08 - val_accuracy: 0.9790 - val_loss: 0.1299
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.1699e-08 - val_accuracy: 0.9770 - val_loss: 0.1304
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.6360e-08 - val_accuracy: 0.9780 - val_loss: 0.1324

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title('Evolución de la función de pérdida')
plt.show()

loss, acc = modelo.evaluate(X_test, y_test)
print(f"\n🔹 Loss: {loss:.4f}  |  Accuracy: {acc:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9717 - loss: 0.1796
#
# 🔹 Loss: 0.1324  |  Accuracy: 0.9780

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score

pred = modelo.predict(X_test)
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Apto', 'Apto'])
disp.plot(cmap='Blues')
plt.show()

sensitivity = recall_score(y_true, y_pred, average=None)
print("\nSensitivity (Recall) por clase:")
print(f"No Apto: {sensitivity[0]:.2f}")
print(f"Apto: {sensitivity[1]:.2f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# Sensitivity (Recall) por clase:
# No Apto: 0.96
# Apto: 0.99

# %%
nuevo_candidato = np.array ([[90, 88, 85, 87, 84, 89,  # técnicas
                              82, 86, 85, 83, 87, 80,  # matemáticas
                              70, 75, 80, 72, 78, 74]]) # psicológicas

nuevo_candidato_scaled = scaler.transform(nuevo_candidato)
pred_nuevo = modelo.predict(nuevo_candidato_scaled)
clase_predicha = np.argmax(pred_nuevo)

print("Evaluación de nuevo candidato:")
print(f"Resultado: {'Apto' if clase_predicha == 1 else 'No Apto'}")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# Evaluación de nuevo candidato:
# Resultado: Apto
